# %% [markdown]
# # ***Check GPU connect***

# %%
print("oke nice")
# Out:
# oke nice

# %%
import torch 

print(torch.__version__) 
print(torch.cuda.is_available()) 
print(torch.cuda.get_device_name(0))
# Out:
# 2.4.0
# True
# Tesla P100-PCIE-16GB

# %%
# !nvidia-smi
# Out:
# Sat Sep 28 08:40:22 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0             25W /  250W |       3MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # ***Content***

# %% [markdown]
# ## Clone dataset

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.15.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
# !git clone https://github.com/QuanHoangNgoc/data-temp.git
# Out:
# Cloning into 'data-temp'...
# remote: Enumerating objects: 18218, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 18218 (delta 0), reused 3 (delta 0), pack-reused 18215 (from 1)
# Receiving objects: 100% (18218/18218), 552.74 MiB | 25.32 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Updating files: 100% (18149/18149), done.

# %% [markdown]
# ## Install

# %%
# !pip -q install sentence-transformers
# !pip -q install faiss-gpu

# %%
import os
from PIL import Image
import numpy as np
import faiss
# from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Check dataset and create image_files

# %%
def get_imagelist(root_folder, glob="jpg"): 
    paths = []
    for dirpath, dirnames, filenames in sorted(os.walk(root_folder)): #!!! must sorted 
        for file in filenames:  
            fullpath = os.path.join(dirpath, file)
            if(fullpath.split(".")[-1] != glob): continue
            paths.append(fullpath) 
    return paths

# %%
image_folder = "/kaggle/working/data-temp"

image_files = get_imagelist(image_folder)
print(len(image_files), image_files[:10]) 
selected_files = random.sample(image_files, 5)

plt.figure(figsize=(20, 5))

for i, file in enumerate(selected_files):
    image = Image.open(file)
    plt.subplot(1, 5, i + 1)
    plt.imshow(image)
    plt.axis("off")

plt.show()
# Out:
# 18148 ['/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_61.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_106.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_135.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_25.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_29.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_151.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_229.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_191.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_215.jpg', '/kaggle/working/data-temp/Keyframes_L07/L07_V001/L07_V001_243.jpg']

# %% [markdown]
# ## Create embeddings and meta

# %%
# # new a embedding model 
# model = SentenceTransformer('clip-ViT-B-32')

# CHUNK_SIZE = 256

# # process each chunk 
# def process_chunk(chunk):
#     images = []
#     for image_file in chunk: images.append(Image.open(image_file))

#     chunk_embeddings = model.encode(images)
#     return chunk_embeddings


# # create the embeddings 
# embeddings = []
# for i in range(0, len(image_files), CHUNK_SIZE):
#     print(i)
#     chunk = image_files[i:i + CHUNK_SIZE]
#     embeddings.extend(process_chunk(chunk))
    
# embeddings

# %%
import gdown  

def drive_down(file_id, name_output_file): 
    url = f'https://drive.google.com/uc?id={file_id}'  
    output = name_output_file  
    gdown.download(url, output, quiet=False)

# %% [markdown]
# ### clone embedding

# %%
file_id = '1XdR4P7RyK68wGruH1Fw2GNyiNpRHYLpT' 
drive_down(file_id, "emb.npy")
embeddings = np.load('emb.npy')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1XdR4P7RyK68wGruH1Fw2GNyiNpRHYLpT
# From (redirected): https://drive.google.com/uc?id=1XdR4P7RyK68wGruH1Fw2GNyiNpRHYLpT&confirm=t&uuid=bd34a3fc-67ce-45e2-ab1d-6de032da84e3
# To: /kaggle/working/emb.npy
# 100%|██████████| 3.48G/3.48G [00:27<00:00, 128MB/s]

# %%
embeddings.shape
# Out:
# (849188, 1024)

# %% [markdown]
# ### clone meta

# %%
file_id = '1B-QZqlyoLW8oc4lyi6_tnV7MoUDA84Z-'
drive_down(file_id, "meta.pkl")

import pickle

with open('meta.pkl', 'rb') as file:
    meta = pickle.load(file)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B-QZqlyoLW8oc4lyi6_tnV7MoUDA84Z-
# To: /kaggle/working/meta.pkl
# 100%|██████████| 16.2M/16.2M [00:00<00:00, 46.1MB/s]

# %%
print(type(meta), len(meta), meta[:10])
# Out:
# <class 'list'> 849188 ['L01_V001_1.jpg', 'L01_V001_2.jpg', 'L01_V001_3.jpg', 'L01_V001_4.jpg', 'L01_V001_5.jpg', 'L01_V001_6.jpg', 'L01_V001_7.jpg', 'L01_V001_8.jpg', 'L01_V001_9.jpg', 'L01_V001_10.jpg']

# %% [markdown]
# ## Create database

# %%
# build vector db 
def create_database(embeddings): 
    dimension = len(embeddings[0])
    db = faiss.IndexFlatIP(dimension)
    db = faiss.IndexIDMap(db)

    # insert embeddings into database 
    vectors = np.array(embeddings).astype('float32')
    db.add_with_ids(vectors, np.array(range(len(embeddings))))
    return db

# %%
db = create_database(embeddings)
db
# Out:
# <faiss.swigfaiss.IndexIDMap; proxy of <Swig Object of type 'faiss::IndexIDMapTemplate< faiss::Index > *' at 0x7f6db0254180> >

# %% [markdown]
# ## Search

# %%
# !pip install sentence-transformers==2.2.2
# !pip install torchscale
# Out:
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (4.44.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (4.66.4)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (2.4.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (0.19.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (1.14.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (0.2.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers==2.2.2) (0.24.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.19.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->sentence-transformers==2.2.2) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==2.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==2.2.2) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->sentence-transformers==2.2.2) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=0d67fc77323e92105b508c71834596eaf761c9715d27abdea403c364818adfa5
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.2
# Collecting torchscale
#   Downloading torchscale-0.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch>=1.8 in /opt/conda/lib/python3.10/site-packages (from torchscale) (2.4.0)
# Collecting fairscale==0.4.0 (from torchscale)
#   Downloading fairscale-0.4.0.tar.gz (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 3.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting timm==0.6.13 (from torchscale)
#   Downloading timm-0.6.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from timm==0.6.13->torchscale) (0.19.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm==0.6.13->torchscale) (6.0.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from timm==0.6.13->torchscale) (0.24.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8->torchscale) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->timm==0.6.13->torchscale) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->timm==0.6.13->torchscale) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->timm==0.6.13->torchscale) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8->torchscale) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8->torchscale) (1.3.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->timm==0.6.13->torchscale) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->timm==0.6.13->torchscale) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub->timm==0.6.13->torchscale) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->timm==0.6.13->torchscale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->timm==0.6.13->torchscale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->timm==0.6.13->torchscale) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->timm==0.6.13->torchscale) (2024.7.4)
# Downloading torchscale-0.3.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 4.4 MB/s eta 0:00:00
# Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 16.8 MB/s eta 0:00:00
# Building wheels for collected packages: fairscale
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.0-py3-none-any.whl size=239917 sha256=2c29840975787101575baa7a06d5c68305336645b306256ce47aa367f2c1ab6b
#   Stored in directory: /root/.cache/pip/wheels/5e/3d/e9/3995d67ff23a09f72bba6380efb35ba97091c7932748884c41
# Successfully built fairscale
# Installing collected packages: fairscale, timm, torchscale
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.8
#     Uninstalling timm-1.0.8:
#       Successfully uninstalled timm-1.0.8
# Successfully installed fairscale-0.4.0 timm-0.6.13 torchscale-0.3.0

# %% [markdown]
# ### set-up beit3 repo

# %%
file_id = '1Xf3XDVR59ONPNemQ0URS7-djDGssfXaN'
drive_down(file_id, "beit3.zip")
# !unzip beit3.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Xf3XDVR59ONPNemQ0URS7-djDGssfXaN
# To: /kaggle/working/beit3.zip
# 100%|██████████| 708k/708k [00:00<00:00, 91.1MB/s]

# %%
# !unzip beit3.zip
# Out:
# Archive:  beit3.zip
#    creating: BEiT3/
#   inflating: BEiT3/beit3.py
#    creating: BEiT3/checkpoints/
#   inflating: BEiT3/checkpoints/beit3.spm
#   inflating: BEiT3/datasets.py
#   inflating: BEiT3/engine_for_finetuning.py
#   inflating: BEiT3/glossary.py
#   inflating: BEiT3/modeling_finetune.py
#   inflating: BEiT3/modeling_utils.py
#   inflating: BEiT3/optim_factory.py
#   inflating: BEiT3/randaug.py
#   inflating: BEiT3/run_beit3_finetuning.py
#   inflating: BEiT3/test_similarity.py
#   inflating: BEiT3/utils_beit.py
#    creating: BEiT3/__pycache__/

# %%
os.listdir('/kaggle/working/BEiT3/checkpoints')
# Out:
# ['beit3.spm']

# %%
file_id = '1e8qULfZLu26e8-wHdtJxCC6wfG72IWMp'
drive_down(file_id, "beit3.pth")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1e8qULfZLu26e8-wHdtJxCC6wfG72IWMp
# From (redirected): https://drive.google.com/uc?id=1e8qULfZLu26e8-wHdtJxCC6wfG72IWMp&confirm=t&uuid=10e435fd-df08-4d53-865a-e75ccad94302
# To: /kaggle/working/beit3.pth
# 100%|██████████| 1.35G/1.35G [00:09<00:00, 142MB/s]

# %% [markdown]
# ### beit3 encoder model

# %%
import BEiT3.beit3 as module

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
checkpoint = "beit3.pth"
sentencepiece_model = os.path.join('/kaggle/working/BEiT3/checkpoints', 'beit3.spm')

# %%
model, transform, tokenizer = module.load_model(device, checkpoint, sentencepiece_model)
# Out:
# /kaggle/working/BEiT3/utils_beit.py:526: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location='cpu')
# Load ckpt from beit3.pth
# Load state_dict by model_key = model
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ### search on db

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.7.4)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.9.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.3 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.7 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.8 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.6 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.9.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.7 MB/s eta 0:00:0000:01
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.2 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=11dbc9780421bcd94b705a47542df8bb6faa7fdba58cd902863493c61825e54b
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.5
#     Uninstalling httpcore-1.0.5:
#       Successfully uninstalled httpcore-1.0.5
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi 0.111.0 requires httpx>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# jupyterlab 4.2.4 requires httpx>=0.25.0, but you have httpx 0.13.3 which is incompatible.
# jupyterlab 4.2.4 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# ydata-profiling 4.9.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.0 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.9.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
from googletrans import Translator
translator = Translator()

# %%
def search(query, db, meta, top_k=100):
    # Query can be image-path or text
    if query.endswith(".jpg"): query = Image.open(query) #!!! not process with image 
    
    text = translator.translate(query, dest='en').text
    emb = module.encode_text(model, tokenizer, text, device)
    print("-", text, emb.shape)
    
    concat_emb = emb.astype("float32").reshape(1, -1)
    rels, indices = db.search(concat_emb, top_k)
    print("-", indices[0][:10])
    print("-", rels[0][:10])

    retrieved_meta = [meta[i] for i in indices[0]]
    print("- ANSWER IS:", retrieved_meta[:10], "\n\n")
    return query, retrieved_meta

# %%
query = "Một con thuyền chạy được trên băng, màu đen. Con thuyền này chạy bằng động cơ cánh quạt ở bên trên thổi hướng ra phía sau. Con thuyền là phương tiện hỗ trợ cứu hộ một nạn nhân bị rơi xuống hồ băng."
search(query, db, meta, top_k=100)
# Out:
# /kaggle/working/BEiT3/beit3.py:432: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), torch.cuda.amp.autocast():
# - A boat that can run on ice, black in color. This boat is powered by a propeller engine on top that blows out the back. The boat was a rescue vehicle for a victim who fell into an icy lake. (1, 1024)
# - [310522 310567 310565 310561 310563 310564 310491 310555 310566 310562]
# - [0.73276746 0.7315209  0.73011756 0.7284763  0.7284543  0.72829175
#  0.72547865 0.7249843  0.7247753  0.7243809 ]
# - ANSWER IS: ['L09_V017_822.jpg', 'L09_V017_867.jpg', 'L09_V017_865.jpg', 'L09_V017_861.jpg', 'L09_V017_863.jpg', 'L09_V017_864.jpg', 'L09_V017_791.jpg', 'L09_V017_855.jpg', 'L09_V017_866.jpg', 'L09_V017_862.jpg']
# ('Một con thuyền chạy được trên băng, màu đen. Con thuyền này chạy bằng động cơ cánh quạt ở bên trên thổi hướng ra phía sau. Con thuyền là phương tiện hỗ trợ cứu hộ một nạn nhân bị rơi xuống hồ băng.',
#  ['L09_V017_822.jpg',
#   'L09_V017_867.jpg',
#   'L09_V017_865.jpg',
#   'L09_V017_861.jpg',
#   'L09_V017_863.jpg',
#   'L09_V017_864.jpg',
#   'L09_V017_791.jpg',
#   'L09_V017_855.jpg',
#   'L09_V017_866.jpg',
#   'L09_V017_862.jpg',
#   'L09_V017_824.jpg',
#   'L09_V017_823.jpg',
#   'L09_V017_859.jpg',
#   'L09_V017_860.jpg',
#   'L09_V017_854.jpg',
#   'L09_V017_857.jpg',
#   'L09_V017_792.jpg',
#   'L09_V017_858.jpg',
#   'L09_V017_856.jpg',
#   'L09_V017_853.jpg',
#   'L09_V017_797.jpg',
#   'L09_V017_796.jpg',
#   'L09_V017_825.jpg',
#   'L09_V017_844.jpg',
#   'L09_V017_849.jpg',
#   'L09_V017_843.jpg',
#   'L09_V017_846.jpg',
#   'L09_V001_868.jpg',
#   'L15_V031_761.jpg',
#   'L15_V031_759.jpg',
#   'L15_V031_762.jpg',
#   'L09_V017_847.jpg',
#   'L09_V017_845.jpg',
#   'L09_V001_869.jpg',
#   'L15_V031_760.jpg',
#   'L09_V017_848.jpg',
#   'L09_V017_850.jpg',
#   'L09_V028_1154.jpg',
#   'L09_V017_842.jpg',
#   'L06_V022_1167.jpg',
#   'L09_V017_851.jpg',
#   'L09_V028_1153.jpg',
#   'L10_V017_449.jpg',
#   'L09_V028_1156.jpg',
#   'L10_V017_483.jpg',
#   'L06_V021_327.jpg',
#   'L09_V028_1157.jpg',
#   'L07_V031_963.jpg',
#   'L09_V028_1158.jpg',
#   'L10_V017_484.jpg',
#   'L06_V005_744.jpg',
#   'L20_V030_1084.jpg',
#   'L10_V022_832.jpg',
#   'L10_V011_802.jpg',
#   'L07_V031_795.jpg',
#   'L20_V030_1082.jpg',
#   'L15_V011_1172.jpg',
#   'L07_V031_938.jpg',
#   'L20_V030_1103.jpg',
#   'L06_V026_1249.jpg',
#   'L06_V005_788.jpg',
#   'L20_V030_1083.jpg',
#   'L07_V031_964.jpg',
#   'L07_V031_991.jpg',
#   'L07_V018_1006.jpg',
#   'L07_V031_794.jpg',
#   'L09_V028_1155.jpg',
#   'L22_V007_456.jpg',
#   'L03_V027_775.jpg',
#   'L09_V017_831.jpg',
#   'L22_V007_457.jpg',
#   'L04_V027_422.jpg',
#   'L10_V002_427.jpg',
#   'L07_V031_992.jpg',
#   'L09_V017_795.jpg',
#   'L06_V005_787.jpg',
#   'L15_V031_763.jpg',
#   'L10_V022_833.jpg',
#   'L09_V017_827.jpg',
#   'L07_V031_965.jpg',
#   'L13_V021_697.jpg',
#   'L04_V027_421.jpg',
#   'L10_V002_713.jpg',
#   'L06_V026_1246.jpg',
#   'L03_V027_771.jpg',
#   'L16_V004_505.jpg',
#   'L12_V010_746.jpg',
#   'L04_V006_398.jpg',
#   'L13_V021_698.jpg',
#   'L03_V027_773.jpg',
#   'L06_V026_1253.jpg',
#   'L06_V026_1256.jpg',
#   'L15_V005_917.jpg',
#   'L06_V005_785.jpg',
#   'L06_V002_647.jpg',
#   'L22_V016_939.jpg',
#   'L06_V005_743.jpg',
#   'L03_V027_772.jpg',
#   'L06_V026_1254.jpg',
#   'L07_V031_796.jpg'])

# %%
def mapping_frame(x): 
    frame_idx = int(x.split('_')[-1].split('.')[0])
    frame_idx = (frame_idx-1) * 25 
    video = x.split('_')[0] + '_' + x.split('_')[1]
    return frame_idx, video 

import csv
def fill(content, need_video):
    _, lst = search(content, db, meta, top_k=1234) #!!! choose a constance 
    new_list = [] 
    for x in lst: 
        frame_idx, video = mapping_frame(x) 
        if(need_video == None): 
            new_list.append([video, frame_idx])
        if(video != need_video): continue
        new_list.append([video, frame_idx])
        
    new_list = new_list[:500]
    print(_, new_list) 
    
    with open("file.csv", 'w', newline='') as csvfile:
        # Create a CSV writer object
        writer = csv.writer(csvfile)

        # Write the data to the CSV file
        writer.writerows(new_list)

# %%
content = 'một chiếc xe máy không có gương chiếu hậu, bên cạnh là dải phân cách làn đường'
fill(content, None) ### check mapping
# Out:
# - a motorbike without a rearview mirror, next to a lane divider (1, 1024)
# - [252422  25765 743727 287465 525357 504456 352629 221975 525355 823435]
# - [0.69922936 0.69124264 0.6911622  0.6850673  0.68440706 0.6838344
#  0.68238723 0.6822317  0.68203336 0.6819752 ]
# - ANSWER IS: ['L08_V001_1251.jpg', 'L01_V023_1111.jpg', 'L21_V006_743.jpg', 'L08_V030_444.jpg', 'L15_V017_498.jpg', 'L14_V027_1165.jpg', 'L10_V021_1220.jpg', 'L07_V006_494.jpg', 'L15_V017_496.jpg', 'L23_V023_224.jpg']
#
#
# một chiếc xe máy không có gương chiếu hậu, bên cạnh là dải phân cách làn đường [['L08_V001', 31250], ['L01_V023', 27750], ['L21_V006', 18550], ['L08_V030', 11075], ['L15_V017', 12425], ['L14_V027', 29100], ['L10_V021', 30475], ['L07_V006', 12325], ['L15_V017', 12375], ['L23_V023', 5575], ['L01_V023', 27800], ['L16_V012', 28325], ['L15_V017', 12400], ['L09_V012', 14175], ['L14_V027', 29150], ['L09_V026', 15750], ['L02_V015', 23100], ['L16_V012', 28300], ['L16_V012', 28275], ['L15_V019', 12475], ['L19_V026', 11150], ['L08_V030', 11050], ['L14_V018', 22100], ['L01_V023', 27775], ['L07_V003', 12400], ['L02_V016', 18775], ['L16_V012', 28350], ['L06_V014', 28100], ['L13_V006', 13900], ['L14_V027', 29125], ['L13_V008', 18600], ['L15_V001', 11550], ['L10_V021', 28525], ['L10_V021', 28550], ['L10_V021', 28375], ['L02_V015', 22375], ['L18_V027', 34825], ['L08_V029', 6075], ['L14_V009', 26250], ['L08_V001', 31275], ['L10_V017', 23025], ['L07_V006', 12300], ['L11_V018', 14925], ['L14_V009', 26275], ['L16_V012', 28200], ['L10_V017', 23050], ['L16_V018', 5350], ['L07_V006', 11850], ['L14_V018', 22050], ['L08_V016', 22650], ['L15_V001', 11525], ['L13_V008', 18575], ['L22_V024', 30800], ['L08_V016', 22600], ['L06_V030', 26775], ['L09_V026', 15900], ['L01_V007', 12975], ['L06_V030', 23050], ['L18_V027', 34800], ['L19_V001', 16425], ['L06_V014', 28125], ['L18_V029', 26175], ['L12_V029', 27800], ['L14_V018', 22075], ['L18_V012', 30625], ['L15_V005', 11350], ['L18_V012', 30725], ['L03_V007', 10725], ['L14_V018', 22125], ['L13_V006', 13775], ['L22_V016', 28775], ['L09_V012', 14400], ['L07_V006', 11900], ['L02_V015', 22675], ['L18_V028', 23700], ['L01_V007', 8750], ['L16_V012', 28250], ['L10_V021', 28250], ['L14_V009', 26225], ['L07_V006', 11875], ['L09_V006', 3425], ['L06_V023', 31675], ['L09_V026', 15800], ['L10_V021', 28325], ['L15_V001', 11500], ['L08_V016', 22675], ['L01_V007', 8775], ['L09_V026', 15775], ['L11_V017', 18750], ['L01_V007', 13275], ['L18_V012', 30475], ['L08_V003', 25250], ['L21_V001', 20025], ['L22_V018', 31700], ['L20_V025', 5175], ['L07_V003', 12450], ['L13_V006', 13875], ['L02_V015', 23000], ['L22_V016', 28800], ['L18_V003', 31125], ['L22_V027', 30425], ['L10_V021', 28350], ['L15_V017', 12475], ['L09_V003', 16625], ['L18_V027', 34850], ['L06_V030', 26750], ['L18_V022', 26750], ['L21_V024', 12375], ['L09_V012', 14275], ['L15_V017', 12450], ['L10_V021', 28275], ['L15_V016', 11850], ['L14_V018', 22150], ['L16_V012', 28225], ['L18_V012', 30400], ['L18_V005', 28100], ['L07_V006', 12250], ['L04_V005', 32225], ['L20_V005', 20550], ['L02_V016', 19125], ['L02_V002', 22600], ['L03_V007', 10025], ['L18_V028', 23725], ['L18_V012', 30650], ['L16_V023', 29850], ['L15_V017', 12625], ['L16_V023', 29825], ['L02_V002', 22575], ['L12_V029', 27775], ['L06_V030', 26725], ['L21_V001', 20050], ['L21_V006', 18575], ['L08_V001', 31575], ['L18_V029', 26150], ['L02_V015', 22650], ['L15_V005', 15350], ['L15_V005', 11325], ['L13_V006', 13800], ['L04_V019', 30750], ['L06_V013', 22225], ['L04_V019', 30775], ['L16_V023', 29800], ['L21_V025', 9150], ['L19_V028', 22175], ['L08_V003', 775], ['L21_V025', 9900], ['L20_V018', 30600], ['L15_V016', 11875], ['L11_V017', 18775], ['L16_V017', 8850], ['L06_V015', 27900], ['L09_V003', 16700], ['L22_V016', 28825], ['L06_V030', 26850], ['L18_V022', 26775], ['L09_V006', 34400], ['L15_V016', 11825], ['L15_V017', 12650], ['L18_V003', 30800], ['L15_V005', 15275], ['L19_V028', 22150], ['L07_V002', 13925], ['L18_V012', 30425], ['L06_V001', 27625], ['L18_V013', 6775], ['L09_V026', 16200], ['L06_V003', 30100], ['L17_V028', 15250], ['L19_V028', 22125], ['L18_V022', 26975], ['L02_V009', 525], ['L07_V006', 12225], ['L04_V019', 30725], ['L18_V012', 30675], ['L19_V018', 15625], ['L12_V010', 28350], ['L07_V007', 11325], ['L10_V021', 28300], ['L18_V022', 27025], ['L09_V003', 16650], ['L03_V011', 26525], ['L10_V021', 30500], ['L16_V017', 8900], ['L18_V029', 25525], ['L18_V022', 26725], ['L18_V012', 30700], ['L11_V007', 15800], ['L08_V02 ...

# %% [markdown]
# ## Main script

# %%
import shutil, csv

def main_submit(in_folder, out_folder, ispair=True):
    if os.path.exists(out_folder): 
        shutil.rmtree(out_folder)
    os.makedirs(out_folder, exist_ok=True)
    print(f"-\/- Remove and renew [{out_folder}]")
    
    for namefile in os.listdir(in_folder):
        with open(os.path.join(in_folder, namefile), 'r') as file:
            # Read the entire file content
            content = file.read()
            content = content.replace("\n", " ")  
            
            # Get retrival list and deformat it 
            _, lst = search(content, db, meta, top_k=100) #!!! main 
            new_list = [] 
            for x in lst: 
                frame_idx, video = mapping_frame(x) #!!! mapping 
                new_list.append([video, frame_idx])
            print(new_list[:10], "\n\n") 
            
            # Write file csv 
            path = os.path.join(out_folder, namefile.replace(".txt", ".csv"))
            with open(path, 'w', newline='') as csvfile:
                # Create a CSV writer object
                writer = csv.writer(csvfile)
    
                # Write the data to the CSV file
                writer.writerows(new_list)

# %%
in_folder = '/kaggle/input/test-de-2/pack2-groupA'
out_folder = '/kaggle/working/submit'
main_submit(in_folder, out_folder, False)
# Out:
# -\/- Remove and renew [/kaggle/working/submit]
# - A man wearing a black shirt and short hair is installing or adjusting a metal plate on the underside of an airplane. Initially it was a frontal angle and then a close-up shot of this person's face. (1, 1024)
# - [288415 288412 288354 288398 288418 288399 288417  94218 557424 288416]
# - [0.7271758  0.70697904 0.7055246  0.699798   0.6917206  0.69130826
#  0.6883579  0.68699145 0.6866149  0.68448555]
# - ANSWER IS: ['L09_V001_81.jpg', 'L09_V001_78.jpg', 'L09_V001_20.jpg', 'L09_V001_64.jpg', 'L09_V001_84.jpg', 'L09_V001_65.jpg', 'L09_V001_83.jpg', 'L03_V020_882.jpg', 'L16_V010_623.jpg', 'L09_V001_82.jpg']
#
#
# [['L09_V001', 2000], ['L09_V001', 1925], ['L09_V001', 475], ['L09_V001', 1575], ['L09_V001', 2075], ['L09_V001', 1600], ['L09_V001', 2050], ['L03_V020', 22025], ['L16_V010', 15550], ['L09_V001', 2025]]
#
#
# - Scene in a bicycle race, the three leading riders take turns wearing blue shirts; green; red yellow black. The race team is going through a bend where there is a sign commemorating the 70th anniversary of the victory of Dien Bien Phu." The word Dien Bien Phu has a rainbow gradient color from right to left. (1, 1024)
# - [815217 823141 815236 463465 505645 503155 479394 404208 479393 816384]
# - [0.7408613  0.7283522  0.72642875 0.7258021  0.7247189  0.7207494
#  0.7201998  0.7199775  0.71934843 0.718328  ]
# - ANSWER IS: ['L23_V001_82.jpg', 'L23_V022_295.jpg', 'L23_V001_101.jpg', 'L13_V023_875.jpg', 'L14_V028_1040.jpg', 'L14_V026_1079.jpg', 'L14_V006_1216.jpg', 'L12_V004_1259.jpg', 'L14_V006_1215.jpg', 'L23_V004_326.jpg']
#
#
# [['L23_V001', 2025], ['L23_V022', 7350], ['L23_V001', 2500], ['L13_V023', 21850], ['L14_V028', 25975], ['L14_V026', 26950], ['L14_V006', 30375], ['L12_V004', 31450], ['L14_V006', 30350], ['L23_V004', 8125]]
#
#
# - The video features the largest ceramic house model in Vietnam in a spring flower festival. (1, 1024)
# - [444216 444215 672875 297692 453424 297693 212211 442116 132610 453423]
# - [0.7931446  0.79127    0.7852303  0.78264457 0.7805945  0.78012747
#  0.77761376 0.77731407 0.7771203  0.77710706]
# - ANSWER IS: ['L13_V006_1114.jpg', 'L13_V006_1113.jpg', 'L19_V011_430.jpg', 'L09_V008_301.jpg', 'L13_V014_906.jpg', 'L09_V008_302.jpg', 'L06_V029_297.jpg', 'L13_V005_222.jpg', 'L04_V023_584.jpg', 'L13_V014_905.jpg']
#
#
# [['L13_V006', 27825], ['L13_V006', 27800], ['L19_V011', 10725], ['L09_V008', 7500], ['L13_V014', 22625], ['L09_V008', 7525], ['L06_V029', 7400], ['L13_V005', 5525], ['L04_V023', 14575], ['L13_V014', 22600]]
#
#
# - The white-haired man walked out holding a glass door with black edges. In front of him was a multicolored flag, including red, yellow, and blue. There were several microphones raised near the man. In it there is a green microphone. Then the camera zoomed closer to this man's face. (1, 1024)
# - [655427 668599 655433 416458 655431 161221 655430 655432 416824 307751]
# - [0.7413816  0.7383616  0.7369015  0.7368909  0.7348268  0.7331667
#  0.7315606  0.73051095 0.72849256 0.72332966]
# - ANSWER IS: ['L18_V025_611.jpg', 'L19_V007_1071.jpg', 'L18_V025_617.jpg', 'L12_V014_475.jpg', 'L18_V025_615.jpg', 'L05_V017_1131.jpg', 'L18_V025_614.jpg', 'L18_V025_616.jpg', 'L12_V014_841.jpg', 'L09_V015_952.jpg']
#
#
# [['L18_V025', 15250], ['L19_V007', 26750], ['L18_V025', 15400], ['L12_V014', 11850], ['L18_V025', 15350], ['L05_V017', 28250], ['L18_V025', 15325], ['L18_V025', 15375], ['L12_V014', 21000], ['L09_V015', 23775]]
#
#
# - A white bull model on a float during a festival. There is smoke coming out of this cow's nostrils. (1, 1024)
# - [832219 842846 121083 832782 831049 838226 838220 833558 832490 844382]
# - [0.7384111  0.7287641  0.7256166  0.720346   0.71909946 0.7178188
#  0.7162328  0.71578807 0.7151728  0.7150642 ]
# - ANSWER IS: ['L24_V014_360.jpg', 'L24_V031_434.jpg', 'L04_V013_1095.jpg', 'L24_V015_397.jpg', 'L24_V011_461.jpg', 'L24_V024_543.jpg', 'L24_V024_537.jpg', 'L24_V017_11.jpg', 'L24_V015_105.jpg', 'L24_V033_571.jpg']
#
#
# [['L24_V014', 8975], ['L24_V031', 10825], ['L04_V013', 27350], ['L24_V015', 9900], ['L24_V011', 11500], ['L24_V024', 13550], ['L24_V024', 13400], ['L24_V017', 250], ['L24_V015', 2600], ['L24_V033', 14250]]
#
#
# - News about a domestic festival. During this festival, there are 2 dragons sailing on the river. There was a person dressed in yellow like an ancient king, holding a piece of brown paper and reading. (1, 1024)
# - [254005 357237 467420 254002  70480 254006  70481 480160 627604 480157]
# - [0.75880706 0.75824916 0.7577043  0.75278014 0.7523677  0.75234395
#  0.7515606  0.7514105  0.7499755  0.7497865 ]
# - ANSWER IS: ['L08_V003_389.jpg', 'L10_V025_522.jpg', 'L13_V027_273.jpg', 'L08_V003_386.jpg', 'L02_V031_345.jpg', 'L08_V003_390.jpg', 'L02_V031_346.jpg', 'L14_V007_594.jpg', 'L18_V005_414.jpg', 'L14_V007_591.jpg']
#
#
# [['L08_V003', 9700], ['L10_V025', 13025], ['L13_V027', 6800], ['L08_V003', 9625], ['L02_V031', 8600], ['L08_V003', 9725], ['L02_V031', 8625], ['L14_V007', 14825], ['L18_V005', 10325], ['L14_V007', 14750]]
#
#
# - The video shows an area decorated with many LED lights. These LED lights are decorated with shapes that resemble lotus flowers, butterflies, spiders, or Halloween pumpkins. There is a person wearing a long coat and glasses taking pictures in the butterfly shaping area. At the end of the video, the boy takes a photo with a pentagonal sphere with a green light inside. (1, 1024)
# - [171280 171255 294657 171256 425490 199171 199182 425489 197784 199172]
# - [0.74272114 0.74111366 0.73645943 0.7351058  0.7315871  0.72921145
#  0.7282962  0.72742724 0.72692144 0.7263314 ]
# - ANSWER IS: ['L05_V026_955.jpg', 'L05_V026_930.jpg', 'L09_V005_1052.jpg', 'L05_V026_931.jpg', 'L12_V021_712.jpg', 'L06_V018_680.jpg', 'L06_V018_691.jpg', 'L12_V021_711.jpg', 'L06_V017_590.jpg', 'L06_V018_681.jpg']
#
#
# [['L05_V026', 23850], ['L05_V026', 23225], ['L09_V005', 26275], ['L05_V026', 23250], ['L12_V021', 17775], ['L06_V018', 16975], ['L06_V018', 17250], ['L12_V021', 17750], ['L06_V017', 14725], ['L06_V018', 17000]]
#
#
# - A white teddy bear is lying face down on a digital scale. There is a camera lens capturing a small animal in this scene. (1, 1024)
# - [329238  25867 328571 113162 579029 578318 730438 222411 399966 752615]
# - [0.6527719  0.65148324 0.6499589  0.6483105  0.6456265  0.6454178
#  0.64499617 0.6447229  0.6431897  0.6427703 ]
# - ANSWER IS: ['L10_V003_1029.jpg', 'L01_V024_57.jpg', 'L10_V003_362.jpg', 'L04_V007_192.jpg', 'L16_V026_232.jpg', 'L16_V025_735.jpg', 'L20_V025_929.jpg', 'L07_V006_930.jpg', 'L12_V001_810.jpg', 'L21_V014_257.jpg']
#
#
# [['L10_V003', 25700], ['L01_V024', 1400], ['L10_V003', 9025], ['L04_V007', 4775], ['L16_V026', 5775], ['L16_V025', 18350], ['L20_V025', 23200], ['L07_V006', 23225], ['L12_V001', 20225], ['L21_V014', 6400]]
#
#
# - Scene of a person climbing a tree to pick fruit, a person in a blue shirt and a person in a black shirt standing below to support. The next scene we know this is a durian tree. Next is a scene of a durian packing factory. (1, 1024)
# - [497385 311398 144156  72991 284438 305957  95870 305955 311429   6796]
# - [0.7427342  0.74062735 0.73773515 0.73523897 0.73455775 0.733166
#  0.730322   0.7272678  0.727242   0.7269026 ]
# - ANSWER IS: ['L14_V022_285.jpg', 'L09_V018_341.jpg', 'L05_V003_325.jpg', 'L03_V002_282.jpg', 'L08_V028_221.jpg', 'L09_V014_487.jpg', 'L03_V022_267.jpg', 'L09_V014_485.jpg', 'L09_V018_372.jpg', 'L01_V007_248.jpg']
#
#
# [['L14_V022', 7100], ['L09_V018', 8500], ['L05_V003', 8100], ['L03_V002', 7025], ['L08_V028', 5500], ['L09_V014', 12150], ['L03_V022', 6650], ['L09_V014', 12100], ['L09_V018', 9275], ['L01_V007', 6175]]
#
#
# - Scene in a classroom, the board below the classroom decorated on the wall can clearly see 5 large flowers in order of blue, orange, yellow, green, red. Below these flowers indicate that this class is class 1A*. Ask * what number is it? (1, 1024)
# - [ 43542 411864 378274 637027  43546 257806 202200 693662  43543 671141]
# - [0.7080916  0.7036265  0.70183414 0.6973338  0.69158155 0.6907392
#  0.69057107 0.6889874  0.68820626 0.68812656]
# - ANSWER IS: ['L02_V008_227.jpg', 'L12_V010_809.jpg', 'L11_V013_536.jpg', 'L18_V011_916.jpg', 'L02_V008_231.jpg', 'L08_V006_387.jpg', 'L06_V021_271.jpg', 'L19_V027_973.jpg', 'L02_V008_228.jpg', 'L19_V010_84.jpg']
#
#
# [['L02_V008', 5650], ['L12_V010', 20200], ['L11_V013', 13375], ['L18_V011', 22875], ['L02_V008', 5750], ['L08_V006', 9650], ['L06_V021', 6750], ['L19_V027', 24300], ['L02_V008', 5675], ['L19_V010', 2075]]
#
#
# - A scene of a person riding a horse running parallel to two people riding a motorbike in an open field. (1, 1024)
# - [720815 720816 720817 575562 575544 575563 575541 575560 575069 575564]
# - [0.6959357  0.6946768  0.69309753 0.6825488  0.68204916 0.6786047
#  0.67807066 0.67562616 0.6742546  0.67349696]
# - ANSWER IS: ['L20_V017_1275.jpg', 'L20_V017_1276.jpg', 'L20_V017_1277.jpg', 'L16_V023_968.jpg', 'L16_V023_950.jpg', 'L16_V023_969.jpg', 'L16_V023_947.jpg', 'L16_V023_966.jpg', 'L16_V023_475.jpg', 'L16_V023_970.jpg']
#
#
# [['L20_V017', 31850], ['L20_V017', 31875], ['L20_V017', 31900], ['L16_V023', 24175], ['L16_V023', 23725], ['L16_V023', 24200], ['L16_V023', 23650], ['L16_V023', 24125], ['L16_V023', 11850], ['L16_V023', 24225]]
#
#
# - The shot of the control room of a vehicle moving at sea is colored blue. In this scene, it can be seen that the control display has a value varying between 210 and 212. (1, 1024)
# - [266355 266356  93788 633071 633072  93766  93765 374827  93786 374828]
# - [0.7499671  0.744388   0.7368921  0.7316079  0.7296963  0.72329336
#  0.72124547 0.72043574 0.71976256 0.71960056]
# - ANSWER IS: ['L08_V013_586.jpg', 'L08_V013_587.jpg', 'L03_V020_452.jpg', 'L18_V008_1339.jpg', 'L18_V008_1340.jpg', 'L03_V020_430.jpg', 'L03_V020_429.jpg', 'L11_V010_409.jpg', 'L03_V020_450.jpg', 'L11_V010_410.jpg']
#
#
# [['L08_V013', 14625], ['L08_V013', 14650], ['L03_V020', 11275], ['L18_V008', 33450], ['L18_V008', 33475], ['L03_V020', 10725], ['L03_V020', 10700], ['L11_V010', 10200], ['L03_V020', 11225], ['L11_V010', 10225]]
#
#
# - Scene of people walking on wooden shoes and making contact with the ground with three stakes on each shoe. Next is the scene of the sheep passing by. Ended with an interview with someone wearing a beige jacket and white shirt underneath. (1, 1024)
# - [704651 217716 250917   9683 679744 250916   9700 374288 704649 679742]
# - [0.71666753 0.7166297  0.71263844 0.71213275 0.71177006 0.71033305
#  0.70540047 0.7030929  0.70242566 0.70200604]
# - ANSWER IS: ['L20_V005_648.jpg', 'L07_V002_815.jpg', 'L07_V031_1040.jpg', 'L01_V009_921.jpg', 'L19_V016_966.jpg', 'L07_V031_1039.jpg', 'L01_V009_938.jpg', 'L11_V009_1208.jpg', 'L20_V005_646.jpg', 'L19_V016_964.jpg']
#
#
# [['L20_V005', 16175], ['L07_V002', 20350], ['L07_V031', 25975], ['L01_V009', 23000], ['L19_V016', 24125], ['L07_V031', 25950], ['L01_V009', 23425], ['L11_V009', 30175], ['L20_V005', 16125], ['L19_V016', 24075]]
#
#
# - A traffic policeman is removing the taxi sign on the roof of an illegally operating taxi. (1, 1024)
# - [ 22860 747445 747444  22859 747454 747452 351108  22861 747453  22862]
# - [0.719257   0.7175992  0.7145883  0.7126723  0.7124669  0.7072605
#  0.70501316 0.6988317  0.6968198  0.6963886 ]
# - ANSWER IS: ['L01_V021_601.jpg', 'L21_V009_857.jpg', 'L21_V009_856.jpg', 'L01_V021_600.jpg', 'L21_V009_866.jpg', 'L21_V009_864.jpg', 'L10_V020_960.jpg', 'L01_V021_602.jpg', 'L21_V009_865.jpg', 'L01_V021_603.jpg']
#
#
# [['L01_V021', 15000], ['L21_V009', 21400], ['L21_V009', 21375], ['L01_V021', 14975], ['L21_V009', 21625], ['L21_V009', 21575], ['L10_V020', 23975], ['L01_V021', 15025], ['L21_V009', 21600], ['L01_V021', 15050]]
#
#
# - A dress is made by assembling small pieces of fabric, each small piece of fabric shaped like a pair of butterfly wings. (1, 1024)
# - [534612 389399 637032 534640 637033 534613 534675 534639 618430 767921]
# - [0.71854156 0.6909181  0.69078237 0.68905926 0.6883018  0.6876229
#  0.6855839  0.6846736  0.6845699  0.68329036]
# - ANSWER IS: ['L15_V024_1115.jpg', 'L11_V022_970.jpg', 'L18_V011_921.jpg', 'L15_V024_1143.jpg', 'L18_V011_922.jpg', 'L15_V024_1116.jpg', 'L15_V024_1178.jpg', 'L15_V024_1142.jpg', 'L17_V027_1306.jpg', 'L21_V027_384.jpg']
#
#
# [['L15_V024', 27850], ['L11_V022', 24225], ['L18_V011', 23000], ['L15_V024', 28550], ['L18_V011', 23025], ['L15_V024', 27875], ['L15_V024', 29425], ['L15_V024', 28525], ['L17_V027', 32625], ['L21_V027', 9575]]
#
#
# - A motorbike was standing on a stand, without a rearview mirror and parked next to, parallel to the median after causing a traffic accident. Then this car was put into a traffic police car. What is the bottom 5 digit number of this motorbike? (1, 1024)
# - [686887 178427  19241 174153 686889 525366  19209  19208 686888 174152]
# - [0.72730666 0.7238798  0.72128016 0.72125727 0.71918666 0.7180013
#  0.7176271  0.717582   0.7173396  0.7160017 ]
# - ANSWER IS: ['L19_V022_585.jpg', 'L06_V001_1106.jpg', 'L01_V018_485.jpg', 'L05_V029_554.jpg', 'L19_V022_587.jpg', 'L15_V017_507.jpg', 'L01_V018_453.jpg', 'L01_V018_452.jpg', 'L19_V022_586.jpg', 'L05_V029_553.jpg']
#
#
# [['L19_V022', 14600], ['L06_V001', 27625], ['L01_V018', 12100], ['L05_V029', 13825], ['L19_V022', 14650], ['L15_V017', 12650], ['L01_V018', 11300], ['L01_V018', 11275], ['L19_V022', 14625], ['L05_V029', 13800]]
#
#
# - The video features a man wearing glasses and jeans giving an interview. This person had a handgun tucked in the back of his pants. The part where the gun is most clearly filmed shows this person putting his hands in his pockets. (1, 1024)
# - [243888 243889 243890 243887 471375 407155 399106 203671  73528 179173]
# - [0.72748166 0.72659886 0.72548395 0.72168833 0.7105798  0.7047953
#  0.70441693 0.7036808  0.7030619  0.7029338 ]
# - ANSWER IS: ['L07_V025_991.jpg', 'L07_V025_992.jpg', 'L07_V025_993.jpg', 'L07_V025_990.jpg', 'L13_V030_819.jpg', 'L12_V006_1390.jpg', 'L11_V030_1117.jpg', 'L06_V022_653.jpg', 'L03_V002_819.jpg', 'L06_V002_699.jpg']
#
#
# [['L07_V025', 24750], ['L07_V025', 24775], ['L07_V025', 24800], ['L07_V025', 24725], ['L13_V030', 20450], ['L12_V006', 34725], ['L11_V030', 27900], ['L06_V022', 16300], ['L03_V002', 20450], ['L06_V002', 17450]]
#
#
# - Scene of a gas station. There was a person going out to fill gas for customers. Then a person ran away because another car drove straight into the gas station. The video switches to another perspective to record this entire collision. The collision caused a gas station in the middle to fall forward. (1, 1024)
# - [501690 501695 501689 593430 501696 593431 593434 395498 165167 593437]
# - [0.75010294 0.7450326  0.74426574 0.7439925  0.7429275  0.7408826
#  0.739378   0.7366237  0.73645747 0.73642975]
# - ANSWER IS: ['L14_V025_835.jpg', 'L14_V025_840.jpg', 'L14_V025_834.jpg', 'L17_V006_734.jpg', 'L14_V025_841.jpg', 'L17_V006_735.jpg', 'L17_V006_738.jpg', 'L11_V028_58.jpg', 'L05_V021_492.jpg', 'L17_V006_741.jpg']
#
#
# [['L14_V025', 20850], ['L14_V025', 20975], ['L14_V025', 20825], ['L17_V006', 18325], ['L14_V025', 21000], ['L17_V006', 18350], ['L17_V006', 18425], ['L11_V028', 1425], ['L05_V021', 12275], ['L17_V006', 18500]]
#
#
# - Video of a man catching a yellow jellyfish in the sea. This person then gave the jellyfish to another person on the boat. (1, 1024)
# - [447643 447642 447641 447650 447649 447647 447634  53301 447653 701904]
# - [0.7599724  0.75781673 0.7569438  0.7565383  0.7556922  0.7541148
#  0.75389785 0.7508269  0.74879265 0.7475111 ]
# - ANSWER IS: ['L13_V009_906.jpg', 'L13_V009_905.jpg', 'L13_V009_904.jpg', 'L13_V009_913.jpg', 'L13_V009_912.jpg', 'L13_V009_910.jpg', 'L13_V009_897.jpg', 'L02_V016_832.jpg', 'L13_V009_916.jpg', 'L20_V003_612.jpg']
#
#
# [['L13_V009', 22625], ['L13_V009', 22600], ['L13_V009', 22575], ['L13_V009', 22800], ['L13_V009', 22775], ['L13_V009', 22725], ['L13_V009', 22400], ['L02_V016', 20775], ['L13_V009', 22875], ['L20_V003', 15275]]
#
#
# - The scene opens with people wearing blue uniforms and yellow belts dancing dragons. Next is a scene of a group of people playing drums. The reportage ends with a scene of a person wearing a white and black ao dai breaking his guitar. The guitar has only 1 string. (1, 1024)
# - [ 79829  34693  79823  33641  79552  79835  79830 759677  79828 467334]
# - [0.78290683 0.7776168  0.7769587  0.7764372  0.7753824  0.77453434
#  0.7742163  0.77279884 0.77195704 0.76868105]
# - ANSWER IS: ['L03_V008_305.jpg', 'L01_V031_888.jpg', 'L03_V008_299.jpg', 'L01_V030_1121.jpg', 'L03_V008_28.jpg', 'L03_V008_311.jpg', 'L03_V008_306.jpg', 'L21_V019_1052.jpg', 'L03_V008_304.jpg', 'L13_V027_187.jpg']
#
#
# [['L03_V008', 7600], ['L01_V031', 22175], ['L03_V008', 7450], ['L01_V030', 28000], ['L03_V008', 675], ['L03_V008', 7750], ['L03_V008', 7625], ['L21_V019', 26275], ['L03_V008', 7575], ['L13_V027', 4650]]
#
#
# - Panning shot of a flower field. The camera pans to a scene of a man in a white shirt digging the ground wearing a blue hat. Next is a person standing and taking a photo of a person sitting. (1, 1024)
# - [339191 339192 339194 339195 478928 721364 339196 662884 721365 283275]
# - [0.7527401  0.7465268  0.74443704 0.7348598  0.73351985 0.73195815
#  0.7305781  0.7231068  0.72299445 0.72181296]
# - ANSWER IS: ['L10_V011_318.jpg', 'L10_V011_319.jpg', 'L10_V011_321.jpg', 'L10_V011_322.jpg', 'L14_V006_750.jpg', 'L20_V018_464.jpg', 'L10_V011_323.jpg', 'L19_V003_354.jpg', 'L20_V018_465.jpg', 'L08_V027_286.jpg']
#
#
# [['L10_V011', 7925], ['L10_V011', 7950], ['L10_V011', 8000], ['L10_V011', 8025], ['L14_V006', 18725], ['L20_V018', 11575], ['L10_V011', 8050], ['L19_V003', 8825], ['L20_V018', 11600], ['L08_V027', 7125]]
#
#
# - The video is represented by a series of consecutive color drawings. The content of the paintings is during a court trial. There is an American flag in one of the paintings. (1, 1024)
# - [ 68106 600703 600702 506792 600704  68107 600695 600696 506791 456778]
# - [0.77334    0.77091604 0.7708171  0.7685048  0.76784086 0.7671044
#  0.76703006 0.76611733 0.7649288  0.76375306]
# - ANSWER IS: ['L02_V029_474.jpg', 'L17_V012_1449.jpg', 'L17_V012_1448.jpg', 'L15_V001_1075.jpg', 'L17_V012_1450.jpg', 'L02_V029_475.jpg', 'L17_V012_1441.jpg', 'L17_V012_1442.jpg', 'L15_V001_1074.jpg', 'L13_V017_1068.jpg']
#
#
# [['L02_V029', 11825], ['L17_V012', 36200], ['L17_V012', 36175], ['L15_V001', 26850], ['L17_V012', 36225], ['L02_V029', 11850], ['L17_V012', 36000], ['L17_V012', 36025], ['L15_V001', 26825], ['L13_V017', 26675]]
#
#
# - News about a location. In this location, there is an Apple logo. Below the logo is the text "robyns" which is equal in size to that logo. (1, 1024)
# - [200107 639963 743966 200108 200002 231595 200106 485346 200003 475866]
# - [0.7189362  0.71834606 0.71790224 0.7177769  0.71711373 0.7166327
#  0.7154     0.71410096 0.714087   0.712932  ]
# - ANSWER IS: ['L06_V019_521.jpg', 'L18_V013_655.jpg', 'L21_V006_982.jpg', 'L06_V019_522.jpg', 'L06_V019_416.jpg', 'L07_V014_707.jpg', 'L06_V019_520.jpg', 'L14_V012_601.jpg', 'L06_V019_417.jpg', 'L14_V004_591.jpg']
#
#
# [['L06_V019', 13000], ['L18_V013', 16350], ['L21_V006', 24525], ['L06_V019', 13025], ['L06_V019', 10375], ['L07_V014', 17650], ['L06_V019', 12975], ['L14_V012', 15000], ['L06_V019', 10400], ['L14_V004', 14750]]
#
#
# - A fishing lure is dropped into the water. This bait looks like a fish, silver in color. Next, the scene changes to a person raising and lowering a fishing rod. This person is wearing a white hat. Video footage of the surrounding area shows many people catching fish. Someone caught a fish and the fish struggled when it was hooked. (1, 1024)
# - [603703 310605 603704  78638 243932 248560 382390 463061 652826 632131]
# - [0.7390724  0.73067844 0.7291221  0.7258276  0.72402847 0.7235241
#  0.7234581  0.7204402  0.7192897  0.7179989 ]
# - ANSWER IS: ['L17_V014_1222.jpg', 'L09_V017_905.jpg', 'L17_V014_1223.jpg', 'L03_V007_150.jpg', 'L07_V025_1035.jpg', 'L07_V029_992.jpg', 'L11_V017_149.jpg', 'L13_V023_471.jpg', 'L18_V023_669.jpg', 'L18_V008_399.jpg']
#
#
# [['L17_V014', 30525], ['L09_V017', 22600], ['L17_V014', 30550], ['L03_V007', 3725], ['L07_V025', 25850], ['L07_V029', 24775], ['L11_V017', 3700], ['L13_V023', 11750], ['L18_V023', 16700], ['L18_V008', 9950]]
#
#
# - Flycam footage of a bridge in Ho Chi Minh City, followed by footage of the Bitexco building. A few scenes then switch to filming the Sword Lake image in Hanoi. (1, 1024)
# - [407282 286117 570372 795333 375564 570373 286116 776855 407284 570374]
# - [0.7740134  0.76543134 0.76427865 0.7641     0.7625924  0.7622556
#  0.7620108  0.76129115 0.7609349  0.76043195]
# - ANSWER IS: ['L12_V007_101.jpg', 'L08_V029_461.jpg', 'L16_V020_206.jpg', 'L22_V017_120.jpg', 'L11_V011_66.jpg', 'L16_V020_207.jpg', 'L08_V029_460.jpg', 'L22_V003_353.jpg', 'L12_V007_103.jpg', 'L16_V020_208.jpg']
#
#
# [['L12_V007', 2500], ['L08_V029', 11500], ['L16_V020', 5125], ['L22_V017', 2975], ['L11_V011', 1625], ['L16_V020', 5150], ['L08_V029', 11475], ['L22_V003', 8800], ['L12_V007', 2550], ['L16_V020', 5175]]
#
#
# - The reportage has a picture with a green background. On the picture is the word "BACK VIEW" written by hand. (1, 1024)
# - [629396 629392 629395 492530 492532 535627 629393 150948 629394 716826]
# - [0.70052695 0.69706464 0.69458544 0.6944125  0.69296825 0.69274646
#  0.6921855  0.68914735 0.6889743  0.68889636]
# - ANSWER IS: ['L18_V006_749.jpg', 'L18_V006_745.jpg', 'L18_V006_748.jpg', 'L14_V018_359.jpg', 'L14_V018_361.jpg', 'L15_V025_789.jpg', 'L18_V006_746.jpg', 'L05_V009_149.jpg', 'L18_V006_747.jpg', 'L20_V014_1123.jpg']
#
#
# [['L18_V006', 18700], ['L18_V006', 18600], ['L18_V006', 18675], ['L14_V018', 8950], ['L14_V018', 9000], ['L15_V025', 19700], ['L18_V006', 18625], ['L05_V009', 3700], ['L18_V006', 18650], ['L20_V014', 28050]]
#
#
# - Scene from an exhibition area. There are two objects that look like jars, on the left side closest to the camera. Next there is a person looking at a clock with a clock face in front and a small tower-like model on top. Next is a scene of paintings placed in golden frames. From left to right are rectangular, elliptical and elliptical frames respectively. (1, 1024)
# - [473549 473550 473548 374168 305240 374167 473571 473579 267255 242807]
# - [0.7181552  0.71339893 0.7124531  0.70217943 0.70157146 0.7005368
#  0.69542915 0.6904257  0.6866375  0.68647766]
# - ANSWER IS: ['L14_V002_667.jpg', 'L14_V002_668.jpg', 'L14_V002_666.jpg', 'L11_V009_1088.jpg', 'L09_V013_1068.jpg', 'L11_V009_1087.jpg', 'L14_V002_689.jpg', 'L14_V002_697.jpg', 'L08_V014_347.jpg', 'L07_V024_853.jpg']
#
#
# [['L14_V002', 16650], ['L14_V002', 16675], ['L14_V002', 16625], ['L11_V009', 27175], ['L09_V013', 26675], ['L11_V009', 27150], ['L14_V002', 17200], ['L14_V002', 17400], ['L08_V014', 8650], ['L07_V024', 21300]]
#
#
# - Two children wearing yellow shirts are sitting on a cyclo. One child is in a sitting position, pedaling a cyclo, and one child is sitting in the front. (1, 1024)
# - [219546 531165 219544 401819 692937 106245 692955 531163 531125 197292]
# - [0.7022667  0.6911182  0.6839124  0.68091136 0.67256486 0.671966
#  0.67145735 0.67111784 0.6701103  0.668954  ]
# - ANSWER IS: ['L07_V004_456.jpg', 'L15_V022_546.jpg', 'L07_V004_454.jpg', 'L12_V003_143.jpg', 'L19_V027_248.jpg', 'L04_V001_483.jpg', 'L19_V027_266.jpg', 'L15_V022_544.jpg', 'L15_V022_506.jpg', 'L06_V017_98.jpg']
#
#
# [['L07_V004', 11375], ['L15_V022', 13625], ['L07_V004', 11325], ['L12_V003', 3550], ['L19_V027', 6175], ['L04_V001', 12050], ['L19_V027', 6625], ['L15_V022', 13575], ['L15_V022', 12625], ['L06_V017', 2425]]
#
#
# - During a drone show there was a panda in the sky. This drone group also performed forming a number. What is the number represented? (1, 1024)
# - [814652 814653 700842 814462 599075 597107 814654 599076 251806 542522]
# - [0.75139916 0.74913794 0.7454855  0.7449923  0.74224305 0.74070096
#  0.73890543 0.7382658  0.7380507  0.7376733 ]
# - ANSWER IS: ['L22_V031_708.jpg', 'L22_V031_709.jpg', 'L20_V002_655.jpg', 'L22_V031_518.jpg', 'L17_V011_938.jpg', 'L17_V010_104.jpg', 'L22_V031_710.jpg', 'L17_V011_939.jpg', 'L08_V001_635.jpg', 'L15_V031_65.jpg']
#
#
# [['L22_V031', 17675], ['L22_V031', 17700], ['L20_V002', 16350], ['L22_V031', 12925], ['L17_V011', 23425], ['L17_V010', 2575], ['L22_V031', 17725], ['L17_V011', 23450], ['L08_V001', 15850], ['L15_V031', 1600]]
#
#
# - Scene shot during a chess competition in Ho Chi Minh City close up on "Table 2". The scene shows the open area for the chess timer between two chess boards. How many chess pieces are there outside the chessboard in this scene? (1, 1024)
# - [ 10110  10108  10109 165524 165500 165498 165522 165501 165523 165489]
# - [0.7830653  0.7743865  0.77421826 0.76091915 0.75741965 0.7571787
#  0.7544713  0.7533486  0.7521771  0.7487756 ]
# - ANSWER IS: ['L01_V010_181.jpg', 'L01_V010_179.jpg', 'L01_V010_180.jpg', 'L05_V021_849.jpg', 'L05_V021_825.jpg', 'L05_V021_823.jpg', 'L05_V021_847.jpg', 'L05_V021_826.jpg', 'L05_V021_848.jpg', 'L05_V021_814.jpg']
#
#
# [['L01_V010', 4500], ['L01_V010', 4450], ['L01_V010', 4475], ['L05_V021', 21200], ['L05_V021', 20600], ['L05_V021', 20550], ['L05_V021', 21150], ['L05_V021', 20625], ['L05_V021', 21175], ['L05_V021', 20325]]

# %%
# Specify the folder to compress and the output ZIP file name  
folder_to_compress = '/kaggle/working/submit' 
output_zip_file = '/kaggle/working/submit.zip'  

# Compress the runs to zip 
shutil.make_archive(output_zip_file.replace('.zip', ''), 'zip', folder_to_compress)
# Out:
# '/kaggle/working/submit.zip'
